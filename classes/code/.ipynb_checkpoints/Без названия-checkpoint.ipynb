# %% [markdown]
# Задания по классам

# %%
import webbrowser
import matplotlib.pyplot as plt
from Bio.Seq import Seq
from Bio.SeqUtils import GC

# %% [markdown]
# 1) Дизайнерский класс

# %%
class Roma_today:
    
    """ 
    Parameters: 
    
    mood: good / bad / angry
    lecturer: No / Yes
    Location: any
    
    """
    
    def __init__(self, mood = "good", lecturer = "No", location = "DAS"):
        
        self.mood = mood
        self.lecturer = lecturer
        self.location = location
        
    def play_xbox(self):
        
        if self.location == "DAS":
            return "Game pass is my LOVE!"
        return "I don't have Xbox here, cannot play directly :("
    
    def help_students(self):
        
        if self.mood == "good":
            webbrowser.open('https://www.youtube.com/watch?v=NMbNwMKarcA')
        elif self.mood == "bad":
            webbrowser.open('https://www.youtube.com/playlist?list=PLjKdf6AHvR-EVtt5ocCAfU2WfJFobZzsD')
        elif self.mood == "angry":
            webbrowser.open('https://www.google.ru')
            
    def drink_beer(self):
        if self.lecturer == "No":
            return True
        elif self.lecturer == "Yes":
            return False

# %%
current_Roma = Roma_today(mood = "angry")

# %%
current_Roma.play_xbox()
# Out:
# 'Game pass is my LOVE!'

# %%
current_Roma.help_students()

# %%
current_Roma.drink_beer()
# Out:
# True

# %% [markdown]
# 2) Класс РНК. Надеюсь я правильно понял как использовать там биопитон

# %%
class RNA:
    
    def __init__(self, sequence):
        self.sequence = Seq(sequence)
    
    def translation(self):
        return self.sequence.translate()
    
    def reverse_transcription(self):
        return self.sequence.back_transcribe()

# %%
rna = RNA("ACGAUCAGU")

# %%
rna.translation()
# Out:
# Seq('TIS')

# %%
rna.reverse_transcription()
# Out:
# Seq('ACGATCAGT')

# %% [markdown]
# Класс, унаследованный от сетов

# %%
class PlusSet(set):
    
    def __init__(self, *args):
        self.elements = [arg for arg in args if arg > 0]
        super().__init__(self.elements)
        
    def add(self, element):
        if element > 0:
            super().add(element)
    
    def update(self, *addings):
        for element in addings:
            self.add(element)

# %%
my = PlusSet(1,1,4,5,-5,-7)

# %%
my
# Out:
# {1, 4, 5}

# %%
my.add(6)

# %%
my
# Out:
# {1, 4, 5, 6}

# %%
my.add(-7)

# %%
my
# Out:
# {1, 4, 5, 6}

# %%
my.update(7,-8)

# %%
my
# Out:
# {1, 4, 5, 6, 7}

# %% [markdown]
# Класс для сбора статистик по фастам

# %%
class Fasta_stat:
    
    def __init__(self, path):
        self.path = path
        
    def __str__(self):
        return self.path
        
    def count_seq(self):
        count = 0
        with open(self.path) as fa:
            for line in fa:
                count += 1
        self.count = count
        return count / 4
    
    def len_hist(self):
        count = 0
        lengths = []
        with open(self.path) as fa:
            for line in fa:
                count += 1
                if count % 4 == 2:
                    lengths.append(len(line))
        plt.hist(lengths)
        plt.title("Histogram of reads' length")
        plt.xlabel("length")
        plt.ylabel("frequency")
        plt.show()
                    
    def gc_part(self):
        count = 0
        overall_len = 0
        gc_len = 0
        with open(self.path) as fa:
            for line in fa:
                count += 1
                if count % 4 == 2:
                    overall_len += len(line)
                    gc_len += GC(line) / 50 * len(line)
        return gc_len / overall_len * 100
        
        
    def four_meer_hist(self):
        count = 0
        four_meers = {}
        with open(self.path) as fa:
            for line in fa:
                count += 1
                if count % 4 == 2:
                    for base in range(len(line)-3):
                        four_mer = line[base : base+4]
                        if four_mer in four_meers:
                            four_meers[four_mer] += 1
                        else:
                            four_meers[four_mer] = 1
        plt.style.use('classic')
        plt.figure(figsize = (12, 8))
        plt.bar(four_meers.keys(), four_meers.values(), width = 1)
        plt.tick_params(axis='x', which='major', labelsize=10)
        plt.xticks(fontsize=3,rotation=90)
        plt.title("Histogram of 4-meers")
        plt.xlabel("name of 4-meer")
        plt.ylabel("frequency")
        plt.show()
        return 
                     
    def stats(self):
        print("number of reads:", self.count_seq())
        print("gc percentage:", self.gc_part())
        print("reads length distribution:")
        self.len_hist()
        print("4-meers frequencies:")
        self.four_meer_hist()
        return

# %%
file = Fasta_stat("../data/reads.fastq")

# %%
file.count_seq()
# Out:
# 17176.0

# %%
file.len_hist()

# %%
file.gc_part()
# Out:
# 86.71456862528183

# %%
file.four_meer_hist()

# %% [markdown]
# Я сдох в попытках нормально визуализировать подписи, так и не могу понять как нормально это сделать. Хелп!

# %%
print(file)
# Out:
# ../data/reads.fastq

# %%
file.stats()
# Out:
# number of reads: 17176.0
# gc percentage: 86.71456862528183
# reads length distribution:
# 4-meers frequencies:
